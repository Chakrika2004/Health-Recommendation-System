# %%
import joblib

# Load your existing model
import pickle
with open("health_model.pkl", "rb") as f:
    model = pickle.load(f)

# Save a compressed version
joblib.dump(model, "health_model_compressed.pkl", compress=3)
# Out:
# ['health_model_compressed.pkl']

# %%
import pickle
import joblib

# Try loading with Pickle
try:
    with open("health_model.pkl", "rb") as f:
        model = pickle.load(f)
    print("✅ Model loaded successfully using Pickle.")
except Exception as e:
    print(f"❌ Pickle failed: {e}")

# Try loading with Joblib
try:
    model = joblib.load("health_model.pkl")
    print("✅ Model loaded successfully using Joblib.")
except Exception as e:
    print(f"❌ Joblib failed: {e}")
# Out:
# ❌ Pickle failed: invalid load key, 'x'.
# ✅ Model loaded successfully using Joblib.
